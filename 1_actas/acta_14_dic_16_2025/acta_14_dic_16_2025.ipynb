# %% [markdown]
# # Acta 14 del 16 de diciembre de 2025

# %% [markdown]
# # Prompt para la estructuración de esta acta
#
# * Corregimos el código JSON de uno de los cuadernos que establece la metodología de consolidación de los datos
#   y la preparación de los datos para el algoritmo SARIMAX.
# * Utilizamos el método `.shift()` de Pandas, para generar los atributos meteorológicos con rezago de 1 a 12
#   semanas epidemiológicas. Qué hace .shift() de Pandas.
# * Revisamos la línea de cóidigo que crea los atributos meteorolígicos con rezago, que consta de la lista de
#   atributos meteorológicos, el ciclo for anidado y la creación de columnas nuevas en un dataframe.
#
# * Las dos fases que siguen con Preprocesamiento de la base de datos y luego el entrenamiento del modelo SARIMAX.
# *

# %% [markdown]
# # ACTA DE ASESORÍA DE TRABAJO DE GRADO
#
# **Proyecto:** Modelo predictivo de epidemias de dengue en el municipio de Caucasia mediante el algoritmo SARIMAX y variables meteorológicas
# **Estudiante:** Janis Zúñiga Ortega
# **Asesor:** Marco Julio Cañas (Docente universitario – Investigador)
# **Programa académico:** *Biología*
# **Grupo / Línea de investigación:** *(especificar si aplica)*
# **Fecha:** *(16, 12 y 2025)*
# **Hora:** *(4 PM – 6 PM)*
# **Modalidad:** Asesoría académica presencial / virtual *(marcar según corresponda)*
# **Lugar:** *Oficina de profesores del Campus Caucasia*
#
# ---
#
# ## 1. Objetivo de la asesoría
#
# Acompañar el proceso investigativo de la estudiante en la **construcción y validación de un modelo SARIMAX** para la predicción de epidemias de dengue en el municipio de Caucasia, con énfasis en la **consolidación, preparación y preprocesamiento de datos meteorológicos y epidemiológicos**, así como en la correcta estructuración metodológica del código en cuadernos Jupyter.
#
# ---
#
# ## 2. Desarrollo de la asesoría
#
# Durante la sesión de asesoría se realizaron las siguientes acciones académicas y técnicas:
#
# ## 2.1 Corrección y validación de la estructura JSON del cuaderno Jupyter
#
# * Se revisó y corrigió el **código JSON** correspondiente a uno de los cuadernos que documenta la **metodología de consolidación y preparación de los datos**.
# * Se garantizaron las condiciones necesarias para que el archivo `.ipynb` pudiera ser **renderizado correctamente en Visual Studio Code**, asegurando la compatibilidad estructural del cuaderno.
# * Se enfatizó la importancia de mantener una estructura JSON válida para asegurar la **reproducibilidad del proceso investigativo**.
#
# ## 2.2 Generación de atributos meteorológicos con rezago
#
# * Se implementó y analizó el uso del método `.shift()` de la biblioteca **Pandas** para la generación de **atributos meteorológicos con rezago temporal**.
# * Se construyeron rezagos desde **1 hasta 12 semanas epidemiológicas**, con el propósito de capturar efectos retardados de las variables climáticas sobre la incidencia del dengue.
# * Se explicó el funcionamiento conceptual del método `.shift()`, destacando su utilidad en el análisis de series de tiempo y en la creación de variables explicativas para modelos autoregresivos.
#
# ### 2.3 Revisión del código para la creación de variables con rezago
#
# * Se revisó detalladamente la línea de código encargada de la creación de los atributos meteorológicos con rezago, analizando:
#
#   * La **lista de variables meteorológicas** seleccionadas.
#   * La estructura del **ciclo `for` anidado** para recorrer variables y rezagos.
#   * La **creación dinámica de nuevas columnas** dentro del `DataFrame`.
# * Se resaltaron buenas prácticas de programación orientadas a la **claridad, escalabilidad y trazabilidad** del código.
#
# ### 2.4 Fases siguientes del proceso metodológico
#
# * Se discutieron y dejaron claramente definidas las dos fases posteriores del proceso investigativo:
#
#   1. **Preprocesamiento de la base de datos**, que incluye limpieza de datos, tratamiento de valores faltantes y verificación de estacionariedad.
#   2. **Entrenamiento del modelo SARIMAX**, abordando la selección de parámetros, ajuste del modelo y evaluación de su desempeño predictivo.
#
# ---
#
# ## 3. Acuerdos y compromisos
#
# * La estudiante continuará con la **implementación del preprocesamiento de datos**, siguiendo las orientaciones metodológicas discutidas.
# * Se avanzará en la **configuración y entrenamiento del modelo SARIMAX**, documentando cada paso en los cuadernos Jupyter.
# * El código y los resultados serán organizados bajo principios de **ciencia abierta y reproducibilidad**, para su posterior análisis y validación.
#
# ---
#
# ## 4. Observaciones finales
#
# La asesoría permitió consolidar aspectos fundamentales de la fase metodológica del trabajo de grado, fortaleciendo la comprensión de la relación entre variables meteorológicas y la dinámica temporal del dengue, así como el uso riguroso de herramientas computacionales para el modelado estadístico.
#
# ---
#
# **Firma del asesor:** _______________________________
# **Firma de la estudiante:** __________________________
#
# ---

# %% [markdown]
# *Esta acta da cuenta de las actividades académicas desarrolladas durante la sesión de asesoría y se incorpora como soporte del proceso de seguimiento al trabajo de grado.*

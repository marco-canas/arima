# %% [markdown]
# # Acta de trabajo investigativo y asesoría semanal
#
# **Estudiante:** Janis Zúñiga Ortega
# **Fecha:** 17 de February de 2026
# **Tipo de encuentro:** Asesoría investigativa semanal

# %% [markdown]
# ## 1. Propósito del encuentro
# Registro del proceso de acompañamiento académico e investigativo semanal.

# %% [markdown]
# ## 2. Desarrollo del trabajo (síntesis del cuaderno Jupyter)

# %% [markdown]
# Tarea:
#
# Se recomienda justificar de manera fundamentada, el porqué no se implementara el algoritmo SARIMAX.

# %% [markdown]
# Se actualizará la base de datos epidemiológica hasta el año 2025.

# %% [markdown]
# Redartar unas recomendaciones y de pronto entregar un una producto en EXCEL que le les facilite a la Secretaría de Salud la toma de datos de manera estructura.

# %% [markdown]
# El profesor Guillermo solicitará a la secretaría de salud los datos del 2025.

# %% [markdown]
# ## Tarea:
#
# Trate de construir un script de python con una aproximación a la automatización de las estructuración de la base de datos epídemiológica entregada por la secretaría de salud.

# %% [markdown]
# Tarea es actualizar el cronograma
#
#
# ## 5. Cronograma acordado
#
# | Etapa | Actividad principal             | Periodo           |
# | ----- | ------------------------------- | ----------------- |
# |0|Tener la base de datos con solo las variables exógenas rezagadas|15 de febrero|
# | 1     | Ajuste final del modelo SARIMAX | 28 Febrero 2026      |
# | 2     | Diagnóstico del modelo          | 15 Marzo 2026        |
# | 3     | Validación y evaluación         | 1 Abril 2026        |
# | 4     | Predicción e interpretación     | 20 de Abril  |
# | 5     | Documentación y cierre          | 1 de Mayo 2026   |
#
# **Fecha límite de consolidación del modelo con medida de desempeño del modelo:** 1 de mayo de 2026.
#
# ---

# %% [markdown]
# #
#
# 1. Preprocesamiento de datos
#    * Visualizar la variable de radiación solar UV
#    * Buscar la estrategia para llenar un periodo de un mes de radiación solar.
#    * Tratamiento de los datos átipicos de los datos meteorológicos de la NASA (-9999).
#    * (escamiento de atributos). Debemos decidir la estrategia de escalonamiento.

# %% [markdown]
# # Visualización de los datos para bísqueda de datos atípicos.

# %% [markdown]
# # Tarea
#
# Inmeditamente despues del cálculo y visualización de las correlaciones de cada atributo meteorológico con el de número de casos, redacte la interpretación por atributo. Elimine del dataset los atributos menos correlación ().

# %% [markdown]
# # Escalonamiento por estandarización.

# %% [markdown]
# # Tarea
#
# Estudiemos los significados de las medidas de dempeño para los algoritmos ARIMA y SARIMAX.

# %% [markdown]
# ## 3. Evidencias computacionales trabajadas

# %% [markdown]
# ```python
# import pandas as pd
#
# df = pd.read_excel(r"C:\Users\marco\OneDrive - Universidad de Antioquia\Documentos\2_recursos_ensenanza\6_datos_arima\Datos_meteorológicos_epidemiológicos_con_rezagos.xlsx")
# ```

# %% [markdown]
# ```python
# df.columns
# ```

# %% [markdown]
# ```python
# df.describe()
# ```

# %% [markdown]
# ```python
# import matplotlib.pyplot as plt
#
# plt.scatter(df.fecha, df['uv (NASA)'])
# ```

# %% [markdown]
# ```python
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Asegurar que la columna fecha sea datetime
# df['fecha'] = pd.to_datetime(df['fecha'])
#
# # Filtrar solo datos del año 2024
# df_2024 = df[df['fecha'].dt.year == 2024]
#
# # Gráfico
# plt.figure(figsize=(10,5))
# plt.scatter(df_2024['fecha'], df_2024['uv (NASA)'])
# plt.xlabel('Fecha')
# plt.ylabel('UV (NASA)')
# plt.title('Radiación UV (NASA) - Año 2024')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
#
# ```

# %% [markdown]
# ```python
# # Actualizar el código para aplicarlo al dataset con los atributos eliminados.
# from sklearn.preprocessing import StandardScaler
# std_scaler = StandardScaler()
# housing_num_std_scaled = std_scaler.fit_transform(dataset)
#
# ```

# %% [markdown]
# ```python
# # Verificar que si quedó bien escalado el dataset
#
# df_escalado.describe()
#
# ```

# %% [markdown]
# ## 4. Orientaciones brindadas
# - Revisión conceptual.
# - Sugerencias metodológicas.
# - Ajustes en organización del trabajo.

# %% [markdown]
# ## 5. Acuerdos y tareas
# - Continuar el desarrollo investigativo.
# - Documentar avances en Jupyter.
# - Fortalecer marco teórico.

# %% [markdown]
# ## 6. Observaciones del asesor
# Se evidencian avances en la apropiación conceptual y computacional del proceso investigativo.

# %% [markdown]
# ## 7. Próximo encuentro
# Seguimiento de avances, revisión de resultados y ajustes metodológicos.

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/investigacion_dengue/blob/main/machine_learning/1_time_series/3_seminario/3_seminario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo]()

# %% [markdown]
# # Seminario 3

# %% [markdown]
# ### Agenda
#
# Presentación de las series de tiempo por parte del profe Nilson
#    * [Tipos y partes de series de tiempo en la lista de reproducción seminario sat-dengue en YouTube](https://www.youtube.com/watch?v=HEpXY6vk5yA)
# Animación en Genialy de la presentación del profe Nilson:[aquí](https://view.genial.ly/64e6152a1f07c1001afa174a/dossier-sales-propuesta-comercial-basica)
#
# Para el próximo seminario:
#    * Visualización con los datos de Antioquia Mira Su Cielo (AMSC)
#
# Generalidades:
#
#    * Acceso a los datos de AMSC [aquí](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/3_datasets/antioquia_mira_su_cielo/datos_desde_inicio/DatosEstacion2022-11-16.csv)
#    * [Segunda forma de acceso a los datos AMSC](http://54.146.188.73:8501/)
#    * [Camiseta para una posible coomunidad python - R](https://pybaq.co/blog/8-anos-en-retrospectiva-python-barranquilla/)

# %% [markdown]
# # Tipos de series de tiempo

# %% [markdown]
# Los datos de series temporales son una forma importante de datos estructurados en muchos campos diferentes, como las finanzas, la economía, la ecología, la neurociencia y la física.

# %% [markdown]
# Todo lo que se observa o mide en muchos puntos en el tiempo forma una serie temporal.

# %% [markdown]
# Muchas series de tiempo son de frecuencia fija, lo que quiere decir que los puntos de datos ocurren a intervalos regulares de acuerdo con alguna regla, como cada 15 segundos, cada 5 minutos o una vez al mes.

# %% [markdown]
# Las series de tiempo también pueden ser irregulares sin una unidad de tiempo fija o compensación entre unidades. La forma en que marca y hace referencia a los datos de series temporales depende de la aplicación, y es posible que tenga uno de los siguientes:

# %% [markdown]
# # Ejemplos de series de Tiempo con Matplotlib

# %% [markdown]
# * Marcas de tiempo, instantes específicos en el tiempo
#
# * Períodos fijos, como el mes de enero de 2007 o el año completo de 2010
#
# * Intervalos de tiempo, indicados por una marca de tiempo de inicio y finalización. Los períodos pueden considerarse como casos especiales de intervalos
#
# * Experimento o tiempo transcurrido; cada marca de tiempo es una medida de tiempo relativa a una hora de inicio particular (por ejemplo, el diámetro de una galleta horneada cada segundo desde que se colocó en el horno)

# %% [markdown]
# Aquí tienes ejemplos de cada uno de los tipos de series de tiempo que mencionaste, junto con cómo graficarlos utilizando la biblioteca Matplotlib en Python:

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta

# Crear un rango de fechas
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 1, 31)
date_range = pd.date_range(start_date, end_date, freq='D')

# Crear datos aleatorios para las series de tiempo
data = [i**2 for i in range(len(date_range))]

# Graficar la serie de tiempo de marcas de tiempo
plt.figure(figsize=(10, 5))
plt.plot(date_range, data, marker='o', linestyle='-', label='Marcas de tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.title('Serie de Tiempo - Marcas de Tiempo')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig('/sysroot/home/marco/Documentos/investigacion/investigacion_dengue/machine_learning/images')

plt.show()

# %%
# Crear una serie de tiempo con instantes específicos
specific_dates = [
    datetime(2023, 1, 5),
    datetime(2023, 1, 15),
    datetime(2023, 1, 25)
]
specific_data = [i**3 for i in range(len(specific_dates))]

# Graficar la serie de tiempo de instantes específicos
plt.figure(figsize=(10, 5))
plt.plot(specific_dates, specific_data, marker='s', linestyle='-', color='orange', label='Instantes específicos')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.title('Serie de Tiempo - Instantes Específicos')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig('/sysroot/home/marco/Documentos/investigacion/investigacion_dengue/machine_learning/images/instantes_especificos.png')

plt.show()

# %%
# Crear una serie de tiempo con períodos fijos
fixed_periods = pd.date_range(start='1/1/2007', end='12/31/2010', freq='M')
fixed_data = [i**4 for i in range(len(fixed_periods))]

# Graficar la serie de tiempo de períodos fijos
plt.figure(figsize=(10, 5))
plt.plot(fixed_periods, fixed_data, marker='^', linestyle='-', color='green', label='Períodos fijos')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.title('Serie de Tiempo - Períodos Fijos')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig('/sysroot/home/marco/Documentos/investigacion/investigacion_dengue/machine_learning/images/periodos_fijos.png')

plt.show()

# %%
# Crear una serie de tiempo con intervalos de tiempo
start_interval = datetime(2023, 1, 1)
end_interval = datetime(2023, 1, 15)
interval_range = pd.date_range(start_interval, end_interval, freq='D')
interval_data = [i**2 for i in range(len(interval_range))]

# Graficar la serie de tiempo de intervalos de tiempo
plt.figure(figsize=(10, 5))
plt.plot(interval_range, interval_data, marker='x', linestyle='-', color='purple', label='Intervalos de tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.title('Serie de Tiempo - Intervalos de Tiempo')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig('/sysroot/home/marco/Documentos/investigacion/investigacion_dengue/machine_learning/images/intervalos.png')

plt.show()

# %% [markdown]
# ### [Video de apoyo a la visualización de tipos de series de tiempo](https://www.youtube.com/watch?v=xvn2OJZqSoo)

# %% [markdown]
# ## Mapa conceptual de síntesis de este seminario

# %%
import networkx as nx

import matplotlib.pyplot as plt 



G = nx.DiGraph() # instancio la clase DiGraph para crear el oobjeto G de esta clase 

plt.figure(figsize = (12, 12))  # Control dell tamaño del mapa conceptual

G.add_node('Serie de\n Tiempo')

G.add_node('Serie de\n Tiempo Tipo 1')
G.add_node('Serie de\n Tiempo Tipo 2')
G.add_node('Serie de\n Tiempo Tipo 3')
G.add_node('Serie de\n Tiempo Tipo 4')

G.add_node('Tipos Datos\n de Python')

G.add_node('Datos tipo\n DateTime')

G.add_edges_from([('Tipos Datos\n de Python', 'Datos tipo\n DateTime')] ) # vincular conceptos con flechas

posicion = nx.spring_layout(G, seed = 513) 

nx.draw(G, posicion, with_labels = True, node_size = 8000)  

plt.savefig('/sysroot/home/marco/Documentos/investigacion/investigacion_dengue/machine_learning/images/mapa_series_tiempo.png')

plt.show()

# %% [markdown]
# # Converting Between String and Datetime
#
# Puede formatear objetos de fecha y hora y objetos de marca de tiempo de pandas, que presentaré más adelante, como cadenas usando `str` o el método strftime, pasando una especificación de formato:

# %%
from datetime import datetime

# %%
marca = datetime(2023, 8, 21)
# Out:
# '2023-08-21 00:00:00'

# %%
marca
# Out:
# datetime.datetime(2023, 8, 21, 0, 0)

# %%
str(marca) # hacemos conversión a cadena de caracteres
# Out:
# '2023-08-21 00:00:00'

# %%
marca.strftime('%Y-%m-%d')
# Out:
# '2023-08-21'

# %% [markdown]
# See Table 11-2 for a complete list of the format codes (reproduced from Chapter 2).
# <img src = 'https://github.com/marco-canas/investigacion_dengue/blob/main/machine_learning/images/table_11_2.jpeg?raw=true'>

# %% [markdown]
# Puede usar estos mismos códigos de formato para convertir cadenas en fechas usando `datetime.strptime`:

# %%
fecha_como_cadena = '2023-08-21'
fecha_como_cadena
# Out:
# '2023-08-21'

# %%
fecha_como_objetoo_datetime = datetime.strptime(fecha_como_cadena, '%Y-%m-%d')
fecha_como_objetoo_datetime
# Out:
# datetime.datetime(2023, 8, 21, 0, 0)

# %%
lista_fechas_como_cadenas = ['8/21/2023', '8/23/2023']
lista_fechas_como_cadenas
# Out:
# ['8/21/2023', '8/23/2023']

# %%
lista_fechas_como_objetos_datetime = [datetime.strptime(x, '%m/%d/%Y') for x in lista_fechas_como_cadenas]
lista_fechas_como_objetos_datetime
# Out:
# [datetime.datetime(2023, 8, 21, 0, 0), datetime.datetime(2023, 8, 23, 0, 0)]

# %% [markdown]
# ### [Video de apoyo](https://www.youtube.com/watch?v=aRG7jDSWgjY)

# %% [markdown]
# `datetime.strptime` es una buena manera de analizar una fecha con un formato conocido. Sin embargo, puede ser un poco molesto tener que escribir una especificación de formato cada vez, especialmente para formatos de fecha comunes. En este caso, puede usar el método `parser.parse` en el paquete `dateutil` de terceros (esto se instala automáticamente cuando instala pandas):

# %%
from dateutil.parser import parse
parse('2023-08-21')
# Out:
# datetime.datetime(2023, 8, 21, 0, 0)

# %% [markdown]
# `dateutil` es capaz de analizar la mayoría de las representaciones de fecha inteligibles por humanos:

# %%
parse('Jan 26, 1975 10:45 PM')
# Out:
# datetime.datetime(1975, 1, 26, 22, 45)

# %% [markdown]
# ## Referentes
#
# * McKinney, W. (2022). Python for data analysis. " O'Reilly Media, Inc.".

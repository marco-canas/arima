# %% [markdown]
# # 02_recoleccion_datos
#
# Proyecto ARIMA / ARIMAX
# Modelación epidemiológica con variables meteorológicas.

# %%
# Inicio del análisis

# %% [markdown]
# # 2. Recolección e integración de datos
#      - Contar la historia con los datos.

# %% [markdown]
# ## 2.1 Datos epidemiológicos
#
# * Casos por fecha
# * Municipio
# * Semana epidemiológica

# %% [markdown]
# # Fuentes posibles:
#
# * Secretaria de salud
#
#
# Variables típicas:
#
# * Procedencia

# %% [markdown]
# # Obtención de los datos epidemiológicos estructurados por Janis e Idalina

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importar datos
ubicacion_janis = r""
ubicacion_marco = r"C:\Users\marco\OneDrive - Universidad de Antioquia\Documentos\2_recursos_ensenanza\6_datos_arima\datos_epidemiologicos_2021-2024.xlsx"
df_epi=pd.read_excel(ubicacion_marco)
df_epi.head(2)
# Out:
#    cod_eve    fec_not  semana   año    cod_pre  cod_sub  edad_  uni_med_  \
# 0      210 2021-01-11       1  2021  515402201        1     40         1
# 1      210 2021-02-06       5  2021  515402201        1     12         1
#
#    nacionali_ nombre_nacionalidad  ...                             nom_upgd  \
# 0         170            COLOMBIA  ...  ESE HOSPITAL CESAR URIBE PIEDRAHITA
# 1         170            COLOMBIA  ...  ESE HOSPITAL CESAR URIBE PIEDRAHITA
#
#   npais_proce ndep_proce nmun_proce npais_resi  ndep_resi nmun_resi  \
# 0    COLOMBIA  ANTIOQUIA   EL BAGRE   COLOMBIA  ANTIOQUIA  EL BAGRE
# 1    COLOMBIA  ANTIOQUIA   ZARAGOZA   COLOMBIA  ANTIOQUIA  ZARAGOZA
#
#    ndep_notif  nmun_notif  nreg
# 0   ANTIOQUIA    CAUCASIA  1800
# 1   ANTIOQUIA    CAUCASIA  1791
#
# [2 rows x 120 columns]

# %% [markdown]
# ## 2.2 Datos meteorológicos
#
# Fuentes posibles:
#
# * NASA POWER
# * IDEAM
# * Antioquia Mira su Cielo
# * Fedearroz
#
# Variables típicas:
#
# * temperatura
# * precipitación
# * humedad
# * radiación
# * velocidad del viento

# %% [markdown]
# # Obtención de los datos meteorológicos o variables exógenas.

# %%
# Importar datos
ubicacion_janis = r"C:\Users\usuario1\OneDrive - Universidad de Antioquia\UNIVERSIDAD DE ANTIOQUIA\Proyecto SAT Dengue\Bases de datos\Datos meteorológicos\NASA POWER\Datos_NS_2021-2024.csv"
ubicacion_marco = r"C:\Users\marco\OneDrive - Universidad de Antioquia\Documentos\2_recursos_ensenanza\6_datos_arima\datos_meteorologicos_2021-2024.csv"
df_meteo=pd.read_csv(ubicacion_marco, sep = ';')
df_meteo.head(2)
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN   QV2M   RH2M  PRECTOTCORR  WS2M  \
# 0  2021    1  28.38    34.96    23.58  16.62  71.66         3.59  0.14
# 1  2021    2  27.44    33.39    23.64  17.98  80.54        12.12  0.10
#
#    WS2M_MAX  WS2M_MIN    UV
# 0      0.24      0.02  2.48
# 1      0.23      0.04  2.18

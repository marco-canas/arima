# %% [markdown]
# # 07_seleccion_modelo
#
# Proyecto ARIMA / SARIMA / ARIMAX / SARIMAX
# Modelación epidemiológica con variables meteorológicas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Ubicación para guardar datos consolidados
ubicacion_datos_consolidados_janis = r"C:\Users\usuario1\OneDrive - Universidad de Antioquia\UNIVERSIDAD DE ANTIOQUIA\Proyecto SAT Dengue\Bases de datos\Datos consolidados"
ubicacion_datos_consolidados_marco = ""
# Ubicación para guardar las imágenes
ubicacion_imagenes_janis = r"C:\Users\usuario1\OneDrive - Universidad de Antioquia\UNIVERSIDAD DE ANTIOQUIA\Proyecto SAT Dengue\Bases de datos\Gráficos\05_ Preprocesamiento"
ubicacion_imagenes_marco = ""

# %%
path_janis = r"C:\Users\usuario1\OneDrive - Universidad de Antioquia\UNIVERSIDAD DE ANTIOQUIA\Proyecto SAT Dengue\Bases de datos\Datos consolidados\datos_modelo_rezagos.xlsx"
path_marco = ""
df_modelo_final = pd.read_excel(path_janis)
df_modelo_final.head()
# Out:
#        fecha   año  semana_epi  casos_ln  hum_esp_mean_lag1_8  \
# 0 2021-03-28  2021          13 -1.667348            -1.562145
# 1 2021-04-04  2021          14 -2.254057            -1.654439
# 2 2021-04-11  2021          15 -2.254057            -1.653274
# 3 2021-04-18  2021          16 -2.254057            -1.571164
# 4 2021-04-25  2021          17 -2.254057            -1.476318
#
#    temp_max_mean_lag1_6  dias_lluvia_mean_lag3_8  vel_vi_max_mean_lag1_6  \
# 0              1.365041                -1.182512               -0.938982
# 1              1.404736                -1.541751               -1.065262
# 2              1.303132                -1.721370               -1.107518
# 3              1.166271                -2.080609               -1.227274
# 4              1.169698                -1.795919               -1.271656
#
#    sst_mean_lag8_12
# 0         -1.471154
# 1         -1.429517
# 2         -1.305834
# 3         -1.389798
# 4         -1.390331

# %% [markdown]
# # Train/Test

# %% [markdown]
# ### Se divide el df cronológicamente en train y test, tomando el 80% de los datos para train y el 20% para test y el 90% de los datos para train y el 10% para test.

# %% [markdown]
# ### División 80/20

# %%
# =========================================================
# DIVISIÓN TRAIN / TEST
# =========================================================

train_size = int(len(df_modelo_final) * 0.80)

train = df_modelo_final.iloc[:train_size]

test = df_modelo_final.iloc[train_size:]

# =========================================================
# VERIFICACIÓN
# =========================================================

print('Train:', train.shape)
print('Test:', test.shape)

print('\nFechas train:')
print(train['fecha'].min(), '->', train['fecha'].max())

print('\nFechas test:')
print(test['fecha'].min(), '->', test['fecha'].max())
# Out:
# Train: (199, 9)
# Test: (50, 9)
#
# Fechas train:
# 2021-03-28 00:00:00 -> 2025-01-12 00:00:00
#
# Fechas test:
# 2025-01-19 00:00:00 -> 2025-12-28 00:00:00

# %% [markdown]
# ### Separación de las variables: endógena y exógenas

# %%
y_train = train['casos_ln']
y_test = test['casos_ln']

# %%
X_train = train[[
    'hum_esp_mean_lag1_8',
    'temp_max_mean_lag1_6',
    'dias_lluvia_mean_lag3_8',
    'vel_vi_max_mean_lag1_6',
    'sst_mean_lag8_12'
]]

X_test = test[[
    'hum_esp_mean_lag1_8',
    'temp_max_mean_lag1_6',
    'dias_lluvia_mean_lag3_8',
    'vel_vi_max_mean_lag1_6',
    'sst_mean_lag8_12'
]]

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/4_didactica_aritmetica/blob/main/modelo_general_clase_aula_invertida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Visualización de dos clases linealemente separables, pero mal clasificadas
#
# ## Metodología
#
# 1. obtener datos
# 2. configurar los datos para la clasificación binaria. (predictores y las etiquetas).
# 3. graficamos los datos como scatter
# 4. trazamos tres rectas clasificadoras.

# %%
# extra code – this cell generates and saves Figure 5–1
# https://github.com/ageron/handson-ml3/blob/main/05_support_vector_machines.ipynb

# importación de las librerías 

from sklearn import datasets                             # importar la librería
iris = datasets.load_iris(as_frame = True)               # crear la variable iris
X = iris.data[['petal length (cm)', 'petal width (cm)']]
y = iris.target                                          # definí o cree la variable objetivo o variable de etiquetas.
X = X.loc[:99] # seleccionar solo los datos correspondientes a las dos primeras clases de flores
y = y.loc[:99]
import numpy as np 
import pandas as pd 
df = pd.DataFrame(np.c_[X.values, y.values], \
             columns = ['longitud', 'ancho', 'tipo de flor'])

import matplotlib.pyplot as plt  

plt.figure()  # crear el lienzo (Yuber Hernany Tapias Arboleda)

plt.title('Gráfico de las flores de iris setosa y virgínica en cuanto a las dimensiones de sus pétalos')

plt.xlabel('longitud del pétalo')

plt.ylabel('ancho del pétalo')

plt.grid() # la red o cuadrícula para facilitar la lectura del gráfico en cuanto a los valores de los atributos predictores
# graficar la clase positiva
plt.scatter(df.longitud.loc[y==0], df.ancho.loc[y==0], color = 'red', marker = 'o',\
            label = '')

# graficar la clase negativa
plt.scatter(df.longitud.loc[y==1], df.ancho.loc[y==1], color = 'green', marker = 's', \
           label = '')

# graficar el mal clasificador


plt.legend()

plt.savefig('setosa_virginica_petalo.jpg')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
